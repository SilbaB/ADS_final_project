# %% [markdown]
# **importing the necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **importing the dataset**

# %%
data=pd.read_csv("Student_performance_data _.csv")

# %%
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
data.shape
# Out:
# (2392, 15)

# %% [markdown]
# *Checking for data types*

# %%
data.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %% [markdown]
# *Converting the GradeClass datatype from float to integer*

# %%
data['GradeClass']=data['GradeClass'].astype(int)
data.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass             int32
# dtype: object

# %%
data=data.drop(columns=['StudentID'],axis=1)

# %% [markdown]
# *Checking for null values*

# %%
data.isna().sum()
# Out:
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
data.GradeClass.value_counts()
# Out:
# GradeClass
# 4    1211
# 3     414
# 2     391
# 1     269
# 0     107
# Name: count, dtype: int64

# %% [markdown]
# **Data visualization**

# %%
sns.set(style="darkgrid")

data.hist('GradeClass')
plt.show()

# %%
sns.set(style="darkgrid")

data.hist('Age')
plt.title('Distribution of Age')
plt.show()

# %%
#The ages were much closer, between 15 and 18 but most of the student had 15 years

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,5))
sns.countplot(x='Gender',data=data)
plt.title('Distribution of Gender')
plt.show()

# %%
#0 represents male and 1 represents female
# more than 1200 of the students were females

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,5))
sns.countplot(x='Ethnicity',data=data)
plt.title('Distribution of Ethnicity')
plt.show()

# %%
#Most of the students,1200 , were from caucasian, followed by African American students,then Asian students
#and students from Other ethncity were less.

# %%
sns.set(style="darkgrid")
data.hist('ParentalEducation')
plt.title('Distribution of ParentalEducation')
plt.show()

# %%
plt.style.use('fivethirtyeight')
#sns.set(style="darkgrid")
plt.figure(figsize=(10,5))
sns.countplot(x='Tutoring',data=data)
plt.title('Distribution of Tutoring')
plt.show()

# %%
#More than 1600 students did not attend tutorials for their study habits while less than 800 attended

# %%
sns.set(style="darkgrid")
data.hist('ParentalSupport')
plt.title('Distribution of ParentalSupport')
plt.show()

# %%
data.ParentalSupport.value_counts()
# Out:
# ParentalSupport
# 2    740
# 3    697
# 1    489
# 4    254
# 0    212
# Name: count, dtype: int64

# %%
# Most of the students received moderate or high support by their parents in ther performance

# %%
data.Extracurricular.value_counts()
# Out:
# Extracurricular
# 0    1475
# 1     917
# Name: count, dtype: int64

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,5))
sns.countplot(x='Extracurricular',data=data)
plt.title('Distribution of Extracurricular activities')
plt.show()

# %%
#  Most of the students,more than 1400, did not participate in Extracurricular activities

# %%
plt.style.use('dark_background')
plt.figure(figsize=(10,5))
sns.countplot(x='Sports',data=data,color='cyan')
plt.title('Distribution of Sports')
plt.show()

# %%
# More than 1600 students did not participate in sports activities

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,5))
sns.countplot(x='Music',data=data)
plt.title('Distribution of Music')
plt.show()

# %%
# Very few students participated in music,less than 500

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,5))
sns.countplot(x='Volunteering',data=data)
plt.title('Distribution of 	Volunteering')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 9 (	) missing from current font.

# %%
data.describe()
# Out:
#                Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000        2392.000000
# mean     16.468645     0.510870     0.877508           1.746237
# std       1.123798     0.499986     1.028476           1.000411
# min      15.000000     0.000000     0.000000           0.000000
# 25%      15.000000     0.000000     0.000000           1.000000
# 50%      16.000000     1.000000     0.000000           2.000000
# 75%      17.000000     1.000000     2.000000           2.000000
# max      18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# min           0.001057     0.000000     0.000000         0.000000
# ...

# %%
for columns in data:
    plt.style.use('ggplot')
    plt.figure(figsize=(7,5))
    plt.hist(x=columns,data=data,color='cyan',edgecolor='black')
    plt.xlabel(f'Distribution of {columns}')
plt.show()

# %%
correlation=data.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, fmt=".02f", cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
import plotly.express as px

# %%
gender_performance = data.groupby('Gender')['GradeClass'].mean().reset_index()
fig=px.bar(gender_performance,x='Gender',y='GradeClass',title='performance per Gender')
fig.show()

# %% [markdown]
# **feature scaling**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = pd.DataFrame(scaler.fit_transform(data.drop('GradeClass', axis=1)), columns=data.columns[:-1])
data_scaled.head(5)
# Out:
#         Age    Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0  0.472919  0.978492  -0.853391           0.253711         1.780336
# 1  1.362944 -1.021981  -0.853391          -0.746087         0.997376
# 2 -1.307132 -1.021981   1.091641           1.253509        -0.984045
# 3  0.472919  0.978492  -0.853391           1.253509         0.045445
# 4  0.472919  0.978492  -0.853391           0.253711        -0.902311
#
#    Absences  Tutoring  ParentalSupport  Extracurricular    Sports     Music  \
# 0 -0.890822  1.522371        -0.108744        -0.788476 -0.660132  2.019544
# 1 -1.717694 -0.656870        -0.999551        -0.788476 -0.660132 -0.495161
# 2  1.353542 -0.656870        -0.108744        -0.788476 -0.660132 -0.495161
# 3 -0.063951 -0.656870         0.782063         1.268269 -0.660132 -0.495161
# 4  0.290422  1.522371         0.782063        -0.788476 -0.660132 -0.495161
#
#    Volunteering       GPA
# 0     -0.431866  1.118086
# 1     -0.431866  1.242374
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

models = {
    "Logistic Regression": LogisticRegression(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machines": SVC(),
    "Decision Trees": DecisionTreeClassifier(),
    "Random Forests": RandomForestClassifier()
}

for name, model in models.items():
    model.fit(X_train, y_train)
    print(f"{name}: {model.score(X_test, y_test)}")
# Out:
# Logistic Regression: 0.7453027139874739
# K-Nearest Neighbors: 0.6200417536534447
# Support Vector Machines: 0.778705636743215
# Decision Trees: 0.8288100208768268
# Random Forests: 0.9123173277661796

# %%
# %%time

from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)

best_model = grid.best_estimator_
print(f"Best model: {best_model}")
print(f"Best score: {grid.best_score_}")
# Out:
# exception calling callback for <Future at 0x15c97fa9510 state=finished raised BrokenProcessPool>
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\joblib\externals\loky\process_executor.py", line 391, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\multiprocessing\queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute '_passthrough_scorer' on <module 'sklearn.metrics._scorer' from 'C:\\Users\\Admin\\anaconda3\\Lib\\site-packages\\sklearn\\metrics\\_scorer.py'>
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...

# %% [markdown]
# **feature_selection using RFECV**

# %%
# %%time
from sklearn.feature_selection import RFECV
from sklearn.metrics import accuracy_score

# Instantiate the best model from Step 4 (e.g., Random Forests)
best_model = RandomForestClassifier(n_estimators=200, max_depth=30, min_samples_split=10, min_samples_leaf=2)

# Create the RFECV object and fit it to the training data
selector = RFECV(best_model, step=1, cv=5, scoring='accuracy')
selector.fit(X_train, y_train)

# Get the selected features and their ranks
selected_features = X_train.columns[selector.support_]
feature_ranks = selector.ranking_

print(f"Selected features: {selected_features}")
print(f"Feature ranks: {feature_ranks}")
# Out:
# Selected features: Index(['StudyTimeWeekly', 'Absences', 'ParentalSupport', 'GPA'], dtype='object')
# Feature ranks: [ 3  9  4  2  1  1  5  1  7  6  8 10  1]
# CPU times: total: 50.1 s
# Wall time: 1min 13s

# %%
# Convert selected_features to a list
selected_features_list = selected_features.tolist()

# Remove target variable from the list of selected features if it's present
if 'GradeClass' in selected_features_list:
    selected_features_list.remove('GradeClass')

# Create new dataframes with only the selected features
X_train_selected = X_train[selected_features_list]
X_test_selected = X_test[selected_features_list]

# %%
best_model=best_model.fit(X_train_selected, y_train)

# Make predictions on the test set
y_pred = best_model.predict(X_test_selected)

# Evaluate the model using accuracy_score
from sklearn.metrics import accuracy_score

test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test accuracy with selected features: {test_accuracy}")
# Out:
# Test accuracy with selected features: 0.9227557411273486

# %%
data.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       1          0                  2        19.833723         7
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
#
#         GPA  GradeClass
# 0  2.929196           2
# 1  3.042915           1
# ...

# %%
X_train=data_scaled

# %%
y_train=data['GradeClass']

# %%
X_train,X_test,y_train,y_test=train_test_split(X_train,y_train,random_state=42,test_size=0.2)

# %%
X_train.shape
# Out:
# (1913, 13)

# %%
y_test.shape
# Out:
# (479,)

# %%
X_test.shape
# Out:
# (479, 13)

# %%
y_train.shape
# Out:
# (1913,)

# %%
X_train.describe()
# Out:
#                Age       Gender    Ethnicity  ParentalEducation  \
# count  1913.000000  1913.000000  1913.000000        1913.000000
# mean     -0.010942     0.007013    -0.004409           0.018004
# std       1.001016     1.000084     1.003589           0.988406
# min      -1.307132    -1.021981    -0.853391          -1.745885
# 25%      -1.307132    -1.021981    -0.853391          -0.746087
# 50%      -0.417106     0.978492    -0.853391           0.253711
# 75%       0.472919     0.978492     1.091641           0.253711
# max       1.362944     0.978492     2.064157           2.253308
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      1913.000000  1913.000000  1913.000000      1913.000000
# mean         -0.004156     0.009097     0.001573         0.016518
# std           1.009054     1.002324     1.000941         0.996197
# min          -1.727648    -1.717694    -0.656870        -1.890357
# ...

# %%
X_train.dtypes
# Out:
# Age                  float64
# Gender               float64
# Ethnicity            float64
# ParentalEducation    float64
# StudyTimeWeekly      float64
# Absences             float64
# Tutoring             float64
# ParentalSupport      float64
# Extracurricular      float64
# Sports               float64
# Music                float64
# Volunteering         float64
# GPA                  float64
# dtype: object

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
params = {
    'objective': 'multi:softmax',  # Use 'multi:softprob' for probability
    'num_class': 5,  # Number of classes
    'eval_metric': 'mlogloss',  # Logarithmic loss for multiclass classification
    'max_depth': 6,  # Maximum depth of the trees
    'learning_rate': 0.1,  # Step size shrinkage
    'n_estimators': 100  # Number of boosting rounds
}
bst = xgb.train(params, dtrain, num_boost_round=100)
dtest = xgb.DMatrix(X_test)
predictions = bst.predict(dtest)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [12:43:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "n_estimators" } are not used.

# %%
predictions
# Out:
# array([4., 1., 3., 0., 4., 2., 3., 3., 3., 4., 3., 4., 2., 3., 2., 4., 4.,
#        4., 3., 3., 4., 4., 4., 1., 4., 4., 4., 1., 3., 3., 3., 4., 2., 1.,
#        4., 4., 1., 2., 1., 4., 2., 0., 4., 3., 4., 3., 2., 4., 2., 4., 1.,
#        1., 4., 4., 4., 1., 3., 1., 4., 3., 4., 3., 3., 4., 4., 4., 1., 3.,
#        4., 1., 0., 4., 2., 2., 4., 2., 3., 4., 4., 4., 3., 1., 3., 4., 4.,
#        4., 0., 4., 4., 4., 2., 4., 4., 4., 4., 4., 1., 4., 4., 4., 4., 3.,
#        4., 4., 4., 3., 2., 4., 4., 4., 4., 3., 0., 4., 4., 4., 3., 2., 4.,
#        3., 4., 1., 0., 4., 4., 4., 2., 4., 3., 2., 4., 0., 2., 4., 4., 4.,
#        3., 4., 4., 4., 2., 4., 1., 4., 2., 4., 4., 2., 1., 4., 1., 4., 1.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 1.,
#        4., 1., 1., 4., 4., 2., 3., 4., 3., 4., 2., 4., 4., 2., 2., 2., 1.,
#        4., 4., 4., 4., 3., 4., 4., 4., 4., 4., 3., 2., 3., 4., 1., 4., 3.,
# ...

# %%
#evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.91

# %%
# Plot feature importance
xgb.plot_importance(bst, importance_type='weight', title='Feature Importance', xlabel='Feature Weight', ylabel='Features')
plt.show()

# %%
# The main factor affecting the performance of the students is their StudyTimeWeekly.
# Number of times a student missed studies determined alot, followed by parental support

# %%
sns.scatterplot(x=predictions,y=y_test);

# %%
# Generate and print classification report
report = classification_report(y_test, predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.59      0.68        22
#            1       0.86      0.86      0.86        49
#            2       0.94      0.85      0.89        85
#            3       0.88      0.90      0.89        86
#            4       0.94      0.99      0.96       237
#
#     accuracy                           0.91       479
#    macro avg       0.88      0.84      0.86       479
# weighted avg       0.91      0.91      0.91       479

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
preds=model.predict(X_test)

# %%
mse=mean_squared_error(y_test,preds)

# %%
mse
# Out:
# 0.5437997812834356

# %%
type(preds)
# Out:
# numpy.ndarray

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
data.Absences.value_counts()
# Out:
# Absences
# 25    93
# 13    93
# 12    92
# 8     91
# 19    90
# 20    90
# 6     88
# 15    87
# 23    86
# 7     86
# 1     85
# 27    84
# 14    84
# 5     83
# 21    83
# 17    81
# 24    81
# 26    80
# 3     79
# 16    79
# 18    79
# 11    71
# 22    71
# 2     69
# 29    69
# 4     69
# 0     67
# 9     67
# 10    61
# 28    54
# Name: count, dtype: int64

# %%
import json
selected_features_list = selected_features.tolist()

with open("selected_features.json", "w") as f:
    json.dump(selected_features_list, f)

# %%
import joblib
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

joblib.dump(model, 'model_filename.pkl')
# Out:
# ['model_filename.pkl']
